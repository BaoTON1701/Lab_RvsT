# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
datafiles = 'chromium_m_h'
data = pd.read_csv(datafiles, sep = '\s+')
# data = np.array(data)

# %%
data
# Out:
#        temps       Champ  Masse        dBdz    Moment         T  (K)
# 0     12.051    5.683308    0.0   -3.250575 -0.000000  44.61288  NaN
# 1     12.656    5.683389    0.0   -3.250618 -0.000000  44.61288  NaN
# 2     13.261    5.683234    0.0   -3.250591 -0.000000  44.61288  NaN
# 3     13.874    5.682954    0.0   -3.250409 -0.000000  44.61288  NaN
# 4     14.478    5.683318    0.0   -3.250695 -0.000000  44.61288  NaN
# ..       ...         ...    ...         ...       ...       ...  ...
# 272  177.180  110.789100 -143.0 -130.518400  1.095631  44.61288  NaN
# 273  177.789  110.793500 -143.0 -130.523800  1.095586  44.61288  NaN
# 274  178.397  110.780200 -143.0 -130.507200  1.095725  44.61288  NaN
# 275  179.004  110.779500 -144.0 -130.506200  1.103396  44.61288  NaN
# 276  179.612  110.774800 -144.0 -130.500500  1.103444  44.61288  NaN
#
# [277 rows x 7 columns]

# %%
plt.plot(data[1], data[4])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 plt.plot(data[1], data[4])
#
# ...
